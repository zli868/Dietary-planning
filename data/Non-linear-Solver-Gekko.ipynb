# %%
import pandas as pd
import numpy as np
from gekko import GEKKO

# %%
# Load the CSV files into DataFrames
df_intake = pd.read_csv("Nutrient_Intake_Recommendations_Formalized.csv")
df_recipe_cost = pd.read_csv("Recipe_Cost_Formalized.csv")
df_recipe_nutrition = pd.read_csv("Recipe_Nutritional_Value_Formalized.csv")

# %% [markdown]
# sample example

# %%
from gekko import GEKKO

# Initialize Model
m = GEKKO(remote=False)
m.options.SOLVER=1
m.solver_options = [#maximum number of nlp solutions from the branch and bound method.
                    #A successful solution is returned if there is an integer solution upon reaching the maximum number of iterations.
                    #Otherwise, the solution is not considered to be successful and an error message is returned with the failed solution.
                    'minlp_maximum_iterations 10000', \
                    # minlp iterations with integer solution
                    'minlp_max_iter_with_int_sol 10', \
                    # maximum number of iterations for each nlp sub-problem.
                    'nlp_maximum_iterations 500', \
                    # 1 means solve minlp problem as a continuous nlp problem, ignoring integer constraints
                    'minlp_as_nlp 0', \
                     #- 1=depth first (find integer solution faster), 2=breadth first, 3=lowest objective leaf, 4=highest objective leaf
                    #* maximum deviation from whole number
                    'minlp_branch_method 3', \
                    'minlp_integer_tol 0.1', \
                    #amount that a candidate solution variable can deviate from an integer solution and still be considered an integer.
                    # covergence tolerance:gap is 
                    #the spread between the lowest candidate leaf (obj_r=non-integer solution) 
                    #and the best integer solution (obj_i). When the gap is below the minlp_gap_tol, 
                    #the best integer solution is returned.
                    'minlp_gap_tol 0.5'
                   ]
#help(m)

#define parameter
eq = m.Param(value=40)

# m.solver_options = ['minlp_maximum_iterations 10000*2']
# m.solver_options = ['minlp_integer_tol 1',\
#                     'minlp_gap_tol 1.0e-2']
#initialize variables
# m.Var(lb=0, integer=True)
x1,x2,x3,x4 = [m.Var(integer=True) for i in range(4)]

#initial values
x1.value = 1
x2.value = 5
x3.value = 5
x4.value = 1

#lower bounds
x1.lower = 1
x2.lower = 1
x3.lower = 1
x4.lower = 1

#upper bounds
x1.upper = 5
x2.upper = 5
x3.upper = 5
x4.upper = 5

#Equations
m.Equation(x1*x2*x3*x4>=25)
m.Equation(x1**2+x2**2+x3**2+x4**2==eq)

#Objective
m.Obj(x1*x4*(x1+x2+x3)+x3)

#Set global options
m.options.IMODE = 3 #steady state optimization

#Solve simulation
m.solve(disp=False) # solve on public server

#Results
print('')
print('Results')
print('x1: ' + str(x1.value))
print('x2: ' + str(x2.value))
print('x3: ' + str(x3.value))
print('x4: ' + str(x4.value))
# Out:
# Results
# x1: [2.0]
# x2: [4.0]
# x3: [2.0]
# x4: [4.0]

# %% [markdown]
# Prediction for one meal

# %%
import pandas as pd
from gekko import GEKKO

# Load the CSV files into DataFrames
df_intake = pd.read_csv("Nutrient_Intake_Recommendations_Formalized.csv")
df_recipe_cost = pd.read_csv("Recipe_Cost_Formalized.csv")
df_recipe_nutrition = pd.read_csv("Recipe_Nutritional_Value_Formalized.csv")

# Extract required data
time_available = 60*1.3 # Example time available (in minutes)

# Define the nutrient requirements dictionary from the df_intake DataFrame
nutrient_requirements = dict(zip(df_intake['Nutrient'], df_intake['Quantity']))

# Initialize gekko model
m = GEKKO(remote=False)
m.options.SOLVER=1
m.solver_options = [#maximum number of nlp solutions from the branch and bound method.
                    #A successful solution is returned if there is an integer solution upon reaching the maximum number of iterations.
                    #Otherwise, the solution is not considered to be successful and an error message is returned with the failed solution.
                    'minlp_maximum_iterations 10000', \
                    # maximum number of nlp solutions when a candidate integer solution is found
                    'minlp_max_iter_with_int_sol 500', \
                    # maximum number of iterations for each nlp sub-problem. lowever value usually save more time
                    'nlp_maximum_iterations 500', \
                    # 1 means solve minlp problem as a continuous nlp problem, ignoring integer constraints
                    'minlp_as_nlp 0', \
                    #- 1=depth first (find integer solution faster), 2=breadth first, 3=lowest objective leaf, 4=highest objective leaf
                    #* maximum deviation from whole number
                    'minlp_branch_method 3', \
                    #amount that a candidate solution variable can deviate from an integer solution and still be considered an integer.
                    'minlp_integer_tol 0.01', \
                    # covergence tolerance:gap is 
                    #the spread between the lowest candidate leaf (obj_r=non-integer solution) 
                    #and the best integer solution (obj_i). When the gap is below the minlp_gap_tol, 
                    #the best integer solution is returned.
                    'minlp_gap_tol 0.01',\
                    # convergence tolerance for the objective function. 
                    'objective_convergence_tolerance 1.0e-6'
                   ]

# Define decision variables
recipes_to_produce = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]

# Define the optimization problem
m.Maximize(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Preference'].values[0] * recipes_to_produce[i] for i, recipe in enumerate(df_recipe_cost['Name'])))

# Constraint 1: time cost
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_available)

# Constraint 2: nutritional requirements
for nutrient in nutrient_requirements:
    m.Equation(sum(df_recipe_nutrition.loc[df_recipe_nutrition['Name'] == recipe, nutrient].values[0] * recipes_to_produce[i] for i, recipe in enumerate(df_recipe_nutrition['Name'])) >= nutrient_requirements[nutrient]/3)

# Solve the optimization problem
m.solve(disp=False)

# Print the results
print("Objective:", -round(m.options.objfcnval, 2))

# Get the quantities and round them to the nearest integer
quantities = [recipe.value[0] for recipe in recipes_to_produce]

# Output dictionary
output = dict(zip(list(df_recipe_cost['Name']), quantities))

# Filter out dishes with a number to make of 0.0
output = {dish: quantity for dish, quantity in output.items() if quantity > 0}

# Calculate time spent for each meal
time_spent = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities[i] for i, recipe in enumerate(df_recipe_cost['Name']))
# Print out time spent for each meal
print("Time spent:", round(time_spent, 2), "minutes")
# Print the filtered output
output
# Out:
# Objective: 9.0
# Time spent: 75.0 minutes
# {'Broccolini Quinoa Pilaf': 1.0,
#  'Vanilla Cream Cakes, Easy and Fluffy Holiday Cakes': 1.0}

# %% [markdown]
# Experiments with the exponential decay

# %%
import pandas as pd
#define decay factor and decay factor multiplier
decay=0.4
decay_mul=1-decay

# Extract required data
time_available = 60*4  # Example time available (in minutes)

# Define the nutrient requirements dictionary from the df_intake DataFrame
nutrient_requirements = dict(zip(df_intake['Nutrient'], df_intake['Quantity']))

# Initialize gekko model
m = GEKKO(remote=False)
m.options.SOLVER=1

# Define decision variables
recipes_to_produce = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]

# Define the optimization problem  ((1-decay_mul**recipes_to_produce[recipe])/(1-decay_mul))
m.Maximize(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Preference'].values[0] * (1-decay_mul**recipes_to_produce[i]) / (1-decay_mul) for i, recipe in enumerate(df_recipe_cost['Name'])))

# Constraint 1: time cost
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_available)

# Constraint 2: nutritional requirements
for nutrient in nutrient_requirements:
    m.Equation(sum(df_recipe_nutrition.loc[df_recipe_nutrition['Name'] == recipe, nutrient].values[0] * recipes_to_produce[i] for i, recipe in enumerate(df_recipe_nutrition['Name'])) >= nutrient_requirements[nutrient]/3)

# Solve the optimization problem
m.solve(disp=False)

# Print the results
print("Objective:", -round(m.options.objfcnval, 2))

# Get the quantities and round them to the nearest integer
quantities = [recipe.value[0] for recipe in recipes_to_produce]

# Output dictionary
output = dict(zip(list(df_recipe_cost['Name']), quantities))

# Filter out dishes with a number to make of 0.0
output = {dish: quantity for dish, quantity in output.items() if quantity > 0}
# Calculate time spent for each meal
time_spent = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities[i] for i, recipe in enumerate(df_recipe_cost['Name']))
# Print out time spent for each meal
print("Time spent:", round(time_spent, 2), "minutes")

output
# Out:
# Objective: 27.0
# Time spent: 240.0 minutes
# {'Beef Braised In Red Wine': 1.0,
#  'Broccolini Quinoa Pilaf': 2.0,
#  'Classic Carrot Cake With Cream Cheese Frosting': 1.0,
#  'Easy Eclairs': 1.0,
#  'Knishes - Potato Filling': 1.0}

# %% [markdown]
# Prediction for three meals. Namely breakfast, lunch and dinner

# %%
# Define the time available for each meal
time_breakfast = 60*0.5  # Example time available for breakfast (in minutes)
time_lunch = 60*1  # Example time available for lunch (in minutes)
time_dinner = 60*2  # Example time available for dinner (in minutes)

# Define the nutrient requirements dictionary from the df_intake DataFrame
nutrient_requirements = dict(zip(df_intake['Nutrient'], df_intake['Quantity']))

# Initialize gekko model
m = GEKKO(remote=False)
m.options.SOLVER=1
m.solver_options = [#maximum number of nlp solutions from the branch and bound method.
                    #A successful solution is returned if there is an integer solution upon reaching the maximum number of iterations.
                    #Otherwise, the solution is not considered to be successful and an error message is returned with the failed solution.
                    'minlp_maximum_iterations 10000', \
                    # maximum number of nlp solutions when a candidate integer solution is found
                    'minlp_max_iter_with_int_sol 500', \
                    # maximum number of iterations for each nlp sub-problem. lowever value usually save more time
                    'nlp_maximum_iterations 500', \
                    # 1 means solve minlp problem as a continuous nlp problem, ignoring integer constraints
                    'minlp_as_nlp 0', \
                    #- 1=depth first (find integer solution faster), 2=breadth first, 3=lowest objective leaf, 4=highest objective leaf
                    #* maximum deviation from whole number
                    'minlp_branch_method 3', \
                    #amount that a candidate solution variable can deviate from an integer solution and still be considered an integer.
                    'minlp_integer_tol 0.01', \
                    # covergence tolerance:gap is 
                    #the spread between the lowest candidate leaf (obj_r=non-integer solution) 
                    #and the best integer solution (obj_i). When the gap is below the minlp_gap_tol, 
                    #the best integer solution is returned.
                    'minlp_gap_tol 0.01',\
                    # convergence tolerance for the objective function. 
                    'objective_convergence_tolerance 1.0e-6'
                   ]
# Define decision variables for each meal
recipes_to_produce_breakfast = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]
recipes_to_produce_lunch = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]
recipes_to_produce_dinner = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]

# Define the optimization problem
m.Maximize(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Preference'].values[0] * 
                (recipes_to_produce_breakfast[i] + recipes_to_produce_lunch[i] + recipes_to_produce_dinner[i])
                for i, recipe in enumerate(df_recipe_cost['Name'])))

# Constraint 1: time cost for each meal
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_breakfast[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_breakfast)
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_lunch[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_lunch)
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_dinner[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_dinner)

# Constraint 2: nutritional requirements: we want that combination all three meals together satisfy the nutritional requirements
for nutrient in nutrient_requirements:
    m.Equation(sum(df_recipe_nutrition.loc[df_recipe_nutrition['Name'] == recipe, nutrient].values[0] *
                    (recipes_to_produce_breakfast[i] + recipes_to_produce_lunch[i] + recipes_to_produce_dinner[i])
                    for i, recipe in enumerate(df_recipe_nutrition['Name'])) >= nutrient_requirements[nutrient])

# Solve the optimization problem
m.solve(disp=False)

# Print the results
print("Objective:", -round(m.options.objfcnval, 2))

# Get the quantities and round them to the nearest integer
quantities_breakfast = [recipe.value[0] for recipe in recipes_to_produce_breakfast]
quantities_lunch = [recipe.value[0] for recipe in recipes_to_produce_lunch]
quantities_dinner = [recipe.value[0] for recipe in recipes_to_produce_dinner]

# Output dictionaries
output_breakfast = dict(zip(list(df_recipe_cost['Name']), quantities_breakfast))
output_lunch = dict(zip(list(df_recipe_cost['Name']), quantities_lunch))
output_dinner = dict(zip(list(df_recipe_cost['Name']), quantities_dinner))


# Filter out dishes with a number to make of 0.0
output_breakfast = {dish: quantity for dish, quantity in output_breakfast.items() if quantity > 0}
output_lunch = {dish: quantity for dish, quantity in output_lunch.items() if quantity > 0}
output_dinner = {dish: quantity for dish, quantity in output_dinner.items() if quantity > 0}
# Calculate time spent for each meal
time_spent_breakfast = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_breakfast[i] for i, recipe in enumerate(df_recipe_cost['Name']))
time_spent_lunch = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_lunch[i] for i, recipe in enumerate(df_recipe_cost['Name']))
time_spent_dinner = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_dinner[i] for i, recipe in enumerate(df_recipe_cost['Name']))

# Print out time spent for each meal
print("Time spent for breakfast:", round(time_spent_breakfast, 2), "minutes")
print("Time spent for lunch:", round(time_spent_lunch, 2), "minutes")
print("Time spent for dinner:", round(time_spent_dinner, 2), "minutes")
# Out:
# Objective: 37.0
# Time spent for breakfast: 30.0 minutes
# Time spent for lunch: 60.0 minutes
# Time spent for dinner: 111.0 minutes

# %%
print("breakfast")
print(output_breakfast)
print("lunch")
print(output_lunch)
print("dinner")
print(output_dinner)
# Out:
# breakfast
# {'Broccolini Quinoa Pilaf': 1.0}
# lunch
# {'Broccolini Quinoa Pilaf': 2.0}
# dinner
# {'Slow Cooker Chicken and Dumplings': 6.0, 'Vanilla Cream Cakes, Easy and Fluffy Holiday Cakes': 1.0}

# %% [markdown]
# Prediction for three meals with exponential decay

# %%
decay=0.4
decay_mul=1-decay

# Define the time available for each meal
time_breakfast = 60*0.5  # Example time available for breakfast (in minutes)
time_lunch = 60*1  # Example time available for lunch (in minutes)
time_dinner = 60*2  # Example time available for dinner (in minutes)

# Define the nutrient requirements dictionary from the df_intake DataFrame
nutrient_requirements = dict(zip(df_intake['Nutrient'], df_intake['Quantity']))

# Initialize gekko model
m = GEKKO(remote=False)
m.options.SOLVER=1
# we have to extend the max_itr since it cannot satisfied easily the convergence tol with default max iteration which is 10000
m.solver_options = [#maximum number of nlp solutions from the branch and bound method.
                    #A successful solution is returned if there is an integer solution upon reaching the maximum number of iterations.
                    #Otherwise, the solution is not considered to be successful and an error message is returned with the failed solution.
                    'minlp_maximum_iterations 10000', \
                    # maximum number of nlp solutions when a candidate integer solution is found
                    'minlp_max_iter_with_int_sol 5000', \
                    # maximum number of iterations for each nlp sub-problem. lowever value usually save more time
                    'nlp_maximum_iterations 200', \
                    # 1 means solve minlp problem as a continuous nlp problem, ignoring integer constraints
                    'minlp_as_nlp 0', \
                    #- 1=depth first (find integer solution faster), 2=breadth first, 3=lowest objective leaf, 4=highest objective leaf
                    #* maximum deviation from whole number
                    'minlp_branch_method 3', \
                    #amount that a candidate solution variable can deviate from an integer solution and still be considered an integer.
                    'minlp_integer_tol 0.06', \
                    # covergence tolerance:gap is 
                    #the spread between the lowest candidate leaf (obj_r=non-integer solution) 
                    #and the best integer solution (obj_i). When the gap is below the minlp_gap_tol, 
                    #the best integer solution is returned.
                    'minlp_gap_tol 0.1',\
                    # convergence tolerance for the objective function. 
                    'objective_convergence_tolerance 1.0e-2'
                   ]

# multiple options as one list

# Define decision variables for each meal
recipes_to_produce_breakfast = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]
recipes_to_produce_lunch = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]
recipes_to_produce_dinner = [m.Var(lb=0, integer=True) for _ in df_recipe_cost['Name']]

# Define the optimization problem
m.Maximize(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Preference'].values[0] * 
               (1-decay_mul**(recipes_to_produce_breakfast[i] + recipes_to_produce_lunch[i] + recipes_to_produce_dinner[i])) / (1-decay_mul) 
                for i, recipe in enumerate(df_recipe_cost['Name'])))


# Constraint 1: time cost for each meal
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_breakfast[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_breakfast)
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_lunch[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_lunch)
m.Equation(sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * recipes_to_produce_dinner[i] for i, recipe in enumerate(df_recipe_cost['Name'])) <= time_dinner)

# Constraint 2: nutritional requirements: we want that combination all three meals together satisfy the nutritional requirements
for nutrient in nutrient_requirements:
    m.Equation(sum(df_recipe_nutrition.loc[df_recipe_nutrition['Name'] == recipe, nutrient].values[0] *
                    (recipes_to_produce_breakfast[i] + recipes_to_produce_lunch[i] + recipes_to_produce_dinner[i])
                    for i, recipe in enumerate(df_recipe_nutrition['Name'])) >= nutrient_requirements[nutrient])

# Solve the optimization problem
m.solve()

# Print the results
print("Maximized preference:", -round(m.options.objfcnval, 2))

# Get the quantities and round them to the nearest integer
quantities_breakfast = [recipe.value[0] for recipe in recipes_to_produce_breakfast]
quantities_lunch = [recipe.value[0] for recipe in recipes_to_produce_lunch]
quantities_dinner = [recipe.value[0] for recipe in recipes_to_produce_dinner]

# Output dictionaries
output_breakfast = dict(zip(list(df_recipe_cost['Name']), quantities_breakfast))
output_lunch = dict(zip(list(df_recipe_cost['Name']), quantities_lunch))
output_dinner = dict(zip(list(df_recipe_cost['Name']), quantities_dinner))

# Filter out dishes with a number to make of 0.0
output_breakfast = {dish: quantity for dish, quantity in output_breakfast.items() if quantity > 0}
output_lunch = {dish: quantity for dish, quantity in output_lunch.items() if quantity > 0}
output_dinner = {dish: quantity for dish, quantity in output_dinner.items() if quantity > 0}
# Filter out dishes with a number to make of 0.0
output_breakfast = {dish: quantity for dish, quantity in output_breakfast.items() if quantity > 0}
output_lunch = {dish: quantity for dish, quantity in output_lunch.items() if quantity > 0}
output_dinner = {dish: quantity for dish, quantity in output_dinner.items() if quantity > 0}

# Calculate time spent for each meal
time_spent_breakfast = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_breakfast[i] for i, recipe in enumerate(df_recipe_cost['Name']))
time_spent_lunch = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_lunch[i] for i, recipe in enumerate(df_recipe_cost['Name']))
time_spent_dinner = sum(df_recipe_cost.loc[df_recipe_cost['Name'] == recipe, 'Time'].values[0] * quantities_dinner[i] for i, recipe in enumerate(df_recipe_cost['Name']))

# Print out time spent for each meal
print("Time spent for breakfast:", round(time_spent_breakfast, 2), "minutes")
print("Time spent for lunch:", round(time_spent_lunch, 2), "minutes")
print("Time spent for dinner:", round(time_spent_dinner, 2), "minutes")
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  0
#    Constants    :  0
#    Variables    :  167
#    Intermediates:  0
#    Connections  :  0
#    Equations    :  30
#    Residuals    :  30
#
#  Number of state variables:    167
#  Number of total equations: -  29
#  Number of slack variables: -  29
#  ---------------------------------------
#  Degrees of freedom       :    109
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.07 NLPi:    6 Dpth:    0 Lvs:    3 Obj: -2.92E+01 Gap:       NaN
# Iter:     2 I: -1 Tm:      0.03 NLPi:    3 Dpth:    1 Lvs:    2 Obj: -2.92E+01 Gap:       NaN
# Iter:     3 I:  0 Tm:      0.03 NLPi:    3 Dpth:    1 Lvs:    4 Obj: -2.92E+01 Gap:       NaN
# Iter:     4 I: -1 Tm:      0.02 NLPi:    3 Dpth:    2 Lvs:    3 Obj: -2.92E+01 Gap:       NaN
# Iter:     5 I:  0 Tm:      0.03 NLPi:    3 Dpth:    2 Lvs:    5 Obj: -2.92E+01 Gap:       NaN
# Iter:     6 I: -1 Tm:      0.02 NLPi:    2 Dpth:    3 Lvs:    4 Obj: -2.92E+01 Gap:       NaN
# Iter:     7 I:  0 Tm:      0.04 NLPi:    5 Dpth:    3 Lvs:    6 Obj: -2.92E+01 Gap:       NaN
# Iter:     8 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:    5 Obj: -2.92E+01 Gap:       NaN
# Iter:     9 I:  0 Tm:      0.03 NLPi:    4 Dpth:    4 Lvs:    7 Obj: -2.86E+01 Gap:       NaN
# Iter:    10 I:  0 Tm:      0.05 NLPi:    6 Dpth:    4 Lvs:    8 Obj: -2.92E+01 Gap:       NaN
# Iter:    11 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:   10 Obj: -2.85E+01 Gap:       NaN
# Iter:    12 I:  0 Tm:      0.03 NLPi:    4 Dpth:    5 Lvs:   11 Obj: -2.92E+01 Gap:       NaN
# Iter:    13 I:  0 Tm:      0.02 NLPi:    3 Dpth:    3 Lvs:   13 Obj: -2.92E+01 Gap:       NaN
# Iter:    14 I: -1 Tm:      0.02 NLPi:    1 Dpth:    4 Lvs:   12 Obj: -2.92E+01 Gap:       NaN
# Iter:    15 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:   11 Obj: -2.92E+01 Gap:       NaN
# Iter:    16 I:  0 Tm:      0.03 NLPi:    3 Dpth:    4 Lvs:   13 Obj: -2.92E+01 Gap:       NaN
# Iter:    17 I:  0 Tm:      0.03 NLPi:    4 Dpth:    2 Lvs:   14 Obj: -2.92E+01 Gap:       NaN
# Iter:    18 I:  0 Tm:      0.03 NLPi:    3 Dpth:    3 Lvs:   16 Obj: -2.92E+01 Gap:       NaN
# Iter:    19 I:  0 Tm:      0.03 NLPi:    4 Dpth:    3 Lvs:   18 Obj: -2.92E+01 Gap:       NaN
# Iter:    20 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:   17 Obj: -2.92E+01 Gap:       NaN
# Iter:    21 I:  0 Tm:      0.03 NLPi:    3 Dpth:    4 Lvs:   19 Obj: -2.91E+01 Gap:       NaN
# Iter:    22 I:  0 Tm:      0.03 NLPi:    4 Dpth:    4 Lvs:   21 Obj: -2.89E+01 Gap:       NaN
# Iter:    23 I: -1 Tm:      0.01 NLPi:    1 Dpth:    4 Lvs:   20 Obj: -2.92E+01 Gap:       NaN
# Iter:    24 I:  0 Tm:      0.04 NLPi:    4 Dpth:    4 Lvs:   22 Obj: -2.86E+01 Gap:       NaN
# Iter:    25 I:  0 Tm:      0.03 NLPi:    4 Dpth:    4 Lvs:   24 Obj: -2.92E+01 Gap:       NaN
# Iter:    26 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:   23 Obj: -2.92E+01 Gap:       NaN
# Iter:    27 I:  0 Tm:      0.04 NLPi:    4 Dpth:    5 Lvs:   25 Obj: -2.85E+01 Gap:       NaN
# Iter:    28 I:  0 Tm:      0.03 NLPi:    4 Dpth:    5 Lvs:   26 Obj: -2.92E+01 Gap:       NaN
# Iter:    29 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:   28 Obj: -2.76E+01 Gap:       NaN
# Iter:    30 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:   29 Obj: -2.92E+01 Gap:       NaN
# Iter:    31 I:  0 Tm:      0.03 NLPi:    3 Dpth:    1 Lvs:   31 Obj: -2.92E+01 Gap:       NaN
# Iter:    32 I: -1 Tm:      0.02 NLPi:    1 Dpth:    2 Lvs:   30 Obj: -2.92E+01 Gap:       NaN
# Iter:    33 I:  0 Tm:      0.03 NLPi:    4 Dpth:    2 Lvs:   32 Obj: -2.92E+01 Gap:       NaN
# Iter:    34 I: -1 Tm:      0.03 NLPi:    3 Dpth:    3 Lvs:   31 Obj: -2.92E+01 Gap:       NaN
# Iter:    35 I:  0 Tm:      0.03 NLPi:    4 Dpth:    3 Lvs:   33 Obj: -2.85E+01 Gap:       NaN
# Iter:    36 I:  0 Tm:      0.03 NLPi:    4 Dpth:    3 Lvs:   34 Obj: -2.92E+01 Gap:       NaN
# Iter:    37 I:  0 Tm:      0.04 NLPi:    4 Dpth:    4 Lvs:   36 Obj: -2.86E+01 Gap:       NaN
# Iter:    38 I:  0 Tm:      0.04 NLPi:    5 Dpth:    4 Lvs:   37 Obj: -2.92E+01 Gap:       NaN
# Iter:    39 I:  0 Tm:      0.05 NLPi:    5 Dpth:    5 Lvs:   39 Obj: -2.76E+01 Gap:       NaN
# Iter:    40 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:   40 Obj: -2.92E+01 Gap:       NaN
# Iter:    41 I:  0 Tm:      0.07 NLPi:    7 Dpth:    2 Lvs:   42 Obj: -2.92E+01 Gap:       NaN
# Iter:    42 I: -1 Tm:      0.02 NLPi:    2 Dpth:    3 Lvs:   41 Obj: -2.92E+01 Gap:       NaN
# Iter:    43 I:  0 Tm:      0.03 NLPi:    4 Dpth:    3 Lvs:   43 Obj: -2.92E+01 Gap:       NaN
# Iter:    44 I:  0 Tm:      0.02 NLPi:    3 Dpth:    3 Lvs:   45 Obj: -2.92E+01 Gap:       NaN
# Iter:    45 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:   47 Obj: -2.85E+01 Gap:       NaN
# Iter:    46 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:   48 Obj: -2.91E+01 Gap:       NaN
# Iter:    47 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:   50 Obj: -2.85E+01 Gap:       NaN
# Iter:    48 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:   51 Obj: -2.91E+01 Gap:       NaN
# Iter:    49 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   53 Obj: -2.85E+01 Gap:       NaN
# Iter:    50 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   54 Obj: -2.91E+01 Gap:       NaN
# Iter:    51 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:   53 Obj: -2.92E+01 Gap:       NaN
# Iter:    52 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:   55 Obj: -2.86E+01 Gap:       NaN
# Iter:    53 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:   56 Obj: -2.92E+01 Gap:       NaN
# Iter:    54 I:  0 Tm:      0.05 NLPi:    5 Dpth:    6 Lvs:   58 Obj: -2.85E+01 Gap:       NaN
# Iter:    55 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:   59 Obj: -2.92E+01 Gap:       NaN
# Iter:    56 I:  0 Tm:      0.04 NLPi:    4 Dpth:    7 Lvs:   61 Obj: -2.85E+01 Gap:       NaN
# Iter:    57 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:   62 Obj: -2.92E+01 Gap:       NaN
# Iter:    58 I: -1 Tm:      0.02 NLPi:    1 Dpth:    8 Lvs:   61 Obj: -2.92E+01 Gap:       NaN
# Iter:    59 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:   62 Obj: -2.90E+01 Gap:       NaN
# Iter:    60 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:   61 Obj: -2.92E+01 Gap:       NaN
# Iter:    61 I:  0 Tm:      0.03 NLPi:    4 Dpth:    4 Lvs:   63 Obj: -2.85E+01 Gap:       NaN
# Iter:    62 I:  0 Tm:      0.04 NLPi:    4 Dpth:    4 Lvs:   64 Obj: -2.92E+01 Gap:       NaN
# Iter:    63 I:  0 Tm:      0.05 NLPi:    6 Dpth:    5 Lvs:   66 Obj: -2.86E+01 Gap:       NaN
# Iter:    64 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:   67 Obj: -2.92E+01 Gap:       NaN
# Iter:    65 I:  0 Tm:      0.05 NLPi:    6 Dpth:    6 Lvs:   69 Obj: -2.85E+01 Gap:       NaN
# Iter:    66 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:   70 Obj: -2.92E+01 Gap:       NaN
# Iter:    67 I: -1 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:   69 Obj: -2.92E+01 Gap:       NaN
# Iter:    68 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   70 Obj: -2.90E+01 Gap:       NaN
# Iter:    69 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:   69 Obj: -2.92E+01 Gap:       NaN
# Iter:    70 I:  0 Tm:      0.03 NLPi:    3 Dpth:    4 Lvs:   71 Obj: -2.84E+01 Gap:       NaN
# Iter:    71 I:  0 Tm:      0.03 NLPi:    3 Dpth:    4 Lvs:   72 Obj: -2.92E+01 Gap:       NaN
# Iter:    72 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:   74 Obj: -2.84E+01 Gap:       NaN
# Iter:    73 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:   75 Obj: -2.90E+01 Gap:       NaN
# Iter:    74 I: -1 Tm:      0.01 NLPi:    1 Dpth:    5 Lvs:   74 Obj: -2.91E+01 Gap:       NaN
# Iter:    75 I:  0 Tm:      0.04 NLPi:    4 Dpth:    5 Lvs:   76 Obj: -2.76E+01 Gap:       NaN
# Iter:    76 I:  0 Tm:      0.05 NLPi:    3 Dpth:    5 Lvs:   77 Obj: -2.91E+01 Gap:       NaN
# Iter:    77 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:   79 Obj: -2.85E+01 Gap:       NaN
# Iter:    78 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:   80 Obj: -2.91E+01 Gap:       NaN
# Iter:    79 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:   82 Obj: -2.82E+01 Gap:       NaN
# Iter:    80 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   83 Obj: -2.91E+01 Gap:       NaN
# Iter:    81 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:   85 Obj: -2.83E+01 Gap:       NaN
# Iter:    82 I:  0 Tm:      0.04 NLPi:    5 Dpth:    8 Lvs:   86 Obj: -2.91E+01 Gap:       NaN
# Iter:    83 I:  0 Tm:      0.05 NLPi:    6 Dpth:    9 Lvs:   88 Obj: -2.86E+01 Gap:       NaN
# Iter:    84 I:  0 Tm:      0.04 NLPi:    5 Dpth:    9 Lvs:   89 Obj: -2.91E+01 Gap:       NaN
# Iter:    85 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:   91 Obj: -2.85E+01 Gap:       NaN
# Iter:    86 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:   92 Obj: -2.91E+01 Gap:       NaN
# Iter:    87 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:   94 Obj: -2.85E+01 Gap:       NaN
# Iter:    88 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:   95 Obj: -2.90E+01 Gap:       NaN
# Iter:    89 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   97 Obj: -2.85E+01 Gap:       NaN
# Iter:    90 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:   99 Obj: -2.91E+01 Gap:       NaN
# Iter:    91 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  101 Obj: -2.85E+01 Gap:       NaN
# Iter:    92 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  102 Obj: -2.90E+01 Gap:       NaN
# Iter:    93 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  104 Obj: -2.85E+01 Gap:       NaN
# Iter:    94 I:  0 Tm:      0.04 NLPi:    4 Dpth:   11 Lvs:  106 Obj: -2.89E+01 Gap:       NaN
# Iter:    95 I: -1 Tm:      0.02 NLPi:    1 Dpth:    8 Lvs:  105 Obj: -2.91E+01 Gap:       NaN
# Iter:    96 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  107 Obj: -2.90E+01 Gap:       NaN
# Iter:    97 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  109 Obj: -2.91E+01 Gap:       NaN
# Iter:    98 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  108 Obj: -2.91E+01 Gap:       NaN
# Iter:    99 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  110 Obj: -2.84E+01 Gap:       NaN
# Iter:   100 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  111 Obj: -2.90E+01 Gap:       NaN
# Iter:   101 I:  0 Tm:      0.05 NLPi:    5 Dpth:    6 Lvs:  113 Obj: -2.85E+01 Gap:       NaN
# Iter:   102 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  114 Obj: -2.90E+01 Gap:       NaN
# Iter:   103 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  116 Obj: -2.85E+01 Gap:       NaN
# Iter:   104 I:  0 Tm:      0.04 NLPi:    3 Dpth:    7 Lvs:  118 Obj: -2.88E+01 Gap:       NaN
# Iter:   105 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  120 Obj: -2.84E+01 Gap:       NaN
# Iter:   106 I:  0 Tm:      0.04 NLPi:    4 Dpth:    8 Lvs:  121 Obj: -2.88E+01 Gap:       NaN
# Iter:   107 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  123 Obj: -2.84E+01 Gap:       NaN
# Iter:   108 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  124 Obj: -2.88E+01 Gap:       NaN
# Iter:   109 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  123 Obj: -2.90E+01 Gap:       NaN
# Iter:   110 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  125 Obj: -2.84E+01 Gap:       NaN
# Iter:   111 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  126 Obj: -2.88E+01 Gap:       NaN
# Iter:   112 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  128 Obj: -2.83E+01 Gap:       NaN
# Iter:   113 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  129 Obj: -2.88E+01 Gap:       NaN
# Iter:   114 I:  0 Tm:      0.04 NLPi:    5 Dpth:    8 Lvs:  131 Obj: -2.85E+01 Gap:       NaN
# Iter:   115 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  132 Obj: -2.90E+01 Gap:       NaN
# Iter:   116 I: -1 Tm:      0.04 NLPi:    3 Dpth:    9 Lvs:  131 Obj: -2.90E+01 Gap:       NaN
# Iter:   117 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  132 Obj: -2.87E+01 Gap:       NaN
# Iter:   118 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  134 Obj: -2.85E+01 Gap:       NaN
# Iter:   119 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  135 Obj: -2.90E+01 Gap:       NaN
# Iter:   120 I: -1 Tm:      0.05 NLPi:    4 Dpth:   10 Lvs:  134 Obj: -2.90E+01 Gap:       NaN
# Iter:   121 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  135 Obj: -2.87E+01 Gap:       NaN
# Iter:   122 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:  134 Obj: -2.89E+01 Gap:       NaN
# Iter:   123 I: -1 Tm:      0.03 NLPi:    2 Dpth:    5 Lvs:  133 Obj: -2.89E+01 Gap:       NaN
# Iter:   124 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:  135 Obj: -2.69E+01 Gap:       NaN
# Iter:   125 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs:  134 Obj: -2.89E+01 Gap:       NaN
# Iter:   126 I:  0 Tm:      0.03 NLPi:    3 Dpth:   12 Lvs:  136 Obj: -2.84E+01 Gap:       NaN
# Iter:   127 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  137 Obj: -2.87E+01 Gap:       NaN
# Iter:   128 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  139 Obj: -2.83E+01 Gap:       NaN
# Iter:   129 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  140 Obj: -2.86E+01 Gap:       NaN
# Iter:   130 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  142 Obj: -2.82E+01 Gap:       NaN
# Iter:   131 I:  0 Tm:      0.04 NLPi:    3 Dpth:   10 Lvs:  143 Obj: -2.86E+01 Gap:       NaN
# Iter:   132 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  145 Obj: -2.82E+01 Gap:       NaN
# Iter:   133 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  146 Obj: -2.86E+01 Gap:       NaN
# Iter:   134 I:  0 Tm:      0.03 NLPi:    4 Dpth:   11 Lvs:  148 Obj: -2.82E+01 Gap:       NaN
# Iter:   135 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  149 Obj: -2.86E+01 Gap:       NaN
# Iter:   136 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  148 Obj: -2.88E+01 Gap:       NaN
# Iter:   137 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  150 Obj: -2.83E+01 Gap:       NaN
# Iter:   138 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  151 Obj: -2.88E+01 Gap:       NaN
# Iter:   139 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  153 Obj: -2.83E+01 Gap:       NaN
# Iter:   140 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  154 Obj: -2.85E+01 Gap:       NaN
# Iter:   141 I:  0 Tm:      0.04 NLPi:    4 Dpth:   10 Lvs:  156 Obj: -2.81E+01 Gap:       NaN
# Iter:   142 I:  0 Tm:      0.04 NLPi:    5 Dpth:   10 Lvs:  157 Obj: -2.87E+01 Gap:       NaN
# Iter:   143 I:  0 Tm:      0.05 NLPi:    6 Dpth:   11 Lvs:  159 Obj: -2.82E+01 Gap:       NaN
# Iter:   144 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  160 Obj: -2.87E+01 Gap:       NaN
# Iter:   145 I:  0 Tm:      0.04 NLPi:    4 Dpth:   12 Lvs:  162 Obj: -2.82E+01 Gap:       NaN
# Iter:   146 I:  0 Tm:      0.03 NLPi:    3 Dpth:   12 Lvs:  163 Obj: -2.87E+01 Gap:       NaN
# Iter:   147 I: -1 Tm:      0.03 NLPi:    3 Dpth:   13 Lvs:  162 Obj: -2.87E+01 Gap:       NaN
# Iter:   148 I:  0 Tm:      0.02 NLPi:    3 Dpth:   13 Lvs:  163 Obj: -2.85E+01 Gap:       NaN
# Iter:   149 I:  0 Tm:      0.03 NLPi:    4 Dpth:   11 Lvs:  165 Obj: -2.83E+01 Gap:       NaN
# Iter:   150 I:  0 Tm:      0.04 NLPi:    4 Dpth:   11 Lvs:  166 Obj: -2.87E+01 Gap:       NaN
# Iter:   151 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  168 Obj: -2.83E+01 Gap:       NaN
# Iter:   152 I:  0 Tm:      0.03 NLPi:    3 Dpth:   12 Lvs:  169 Obj: -2.87E+01 Gap:       NaN
# Iter:   153 I: -1 Tm:      0.04 NLPi:    3 Dpth:   13 Lvs:  168 Obj: -2.87E+01 Gap:       NaN
# Iter:   154 I:  0 Tm:      0.03 NLPi:    4 Dpth:   13 Lvs:  169 Obj: -2.85E+01 Gap:       NaN
# Iter:   155 I:  0 Tm:      0.03 NLPi:    3 Dpth:   13 Lvs:  171 Obj: -2.82E+01 Gap:       NaN
# Iter:   156 I:  0 Tm:      0.03 NLPi:    4 Dpth:   13 Lvs:  172 Obj: -2.83E+01 Gap:       NaN
# Iter:   157 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  174 Obj: -2.81E+01 Gap:       NaN
# Iter:   158 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  175 Obj: -2.84E+01 Gap:       NaN
# Iter:   159 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  177 Obj: -2.81E+01 Gap:       NaN
# Iter:   160 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  178 Obj: -2.83E+01 Gap:       NaN
# Iter:   161 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  180 Obj: -2.81E+01 Gap:       NaN
# Iter:   162 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  181 Obj: -2.83E+01 Gap:       NaN
# Iter:   163 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  183 Obj: -2.81E+01 Gap:       NaN
# Iter:   164 I:  0 Tm:      0.04 NLPi:    4 Dpth:   12 Lvs:  184 Obj: -2.83E+01 Gap:       NaN
# Iter:   165 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  183 Obj: -2.86E+01 Gap:       NaN
# Iter:   166 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  185 Obj: -2.78E+01 Gap:       NaN
# Iter:   167 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  186 Obj: -2.86E+01 Gap:       NaN
# Iter:   168 I: -1 Tm:      0.03 NLPi:    2 Dpth:    5 Lvs:  185 Obj: -2.86E+01 Gap:       NaN
# Iter:   169 I:  0 Tm:      0.03 NLPi:    4 Dpth:    5 Lvs:  187 Obj: -2.86E+01 Gap:       NaN
# Iter:   170 I:  0 Tm:      0.04 NLPi:    4 Dpth:    5 Lvs:  189 Obj: -2.86E+01 Gap:       NaN
# Iter:   171 I: -1 Tm:      0.04 NLPi:    3 Dpth:    7 Lvs:  188 Obj: -2.86E+01 Gap:       NaN
# Iter:   172 I:  0 Tm:      0.04 NLPi:    5 Dpth:    7 Lvs:  189 Obj: -2.85E+01 Gap:       NaN
# Iter:   173 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:  188 Obj: -2.86E+01 Gap:       NaN
# Iter:   174 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:  190 Obj: -2.86E+01 Gap:       NaN
# Iter:   175 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:  192 Obj: -2.86E+01 Gap:       NaN
# Iter:   176 I: -1 Tm:      0.01 NLPi:    1 Dpth:    6 Lvs:  191 Obj: -2.86E+01 Gap:       NaN
# Iter:   177 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  193 Obj: -2.86E+01 Gap:       NaN
# Iter:   178 I:  0 Tm:      0.04 NLPi:    4 Dpth:    6 Lvs:  195 Obj: -2.84E+01 Gap:       NaN
# Iter:   179 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:  194 Obj: -2.86E+01 Gap:       NaN
# Iter:   180 I:  0 Tm:      0.03 NLPi:    4 Dpth:    5 Lvs:  196 Obj: -2.86E+01 Gap:       NaN
# Iter:   181 I:  0 Tm:      0.03 NLPi:    3 Dpth:    5 Lvs:  198 Obj: -2.86E+01 Gap:       NaN
# Iter:   182 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  197 Obj: -2.86E+01 Gap:       NaN
# Iter:   183 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  199 Obj: -2.86E+01 Gap:       NaN
# Iter:   184 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  201 Obj: -2.86E+01 Gap:       NaN
# Iter:   185 I: -1 Tm:      0.01 NLPi:    1 Dpth:    6 Lvs:  200 Obj: -2.86E+01 Gap:       NaN
# Iter:   186 I: -1 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  199 Obj: -2.86E+01 Gap:       NaN
# Iter:   187 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  201 Obj: -2.84E+01 Gap:       NaN
# Iter:   188 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  200 Obj: -2.86E+01 Gap:       NaN
# Iter:   189 I:  0 Tm:      0.04 NLPi:    4 Dpth:    6 Lvs:  202 Obj: -2.78E+01 Gap:       NaN
# Iter:   190 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:  203 Obj: -2.86E+01 Gap:       NaN
# Iter:   191 I:  0 Tm:      0.04 NLPi:    5 Dpth:    7 Lvs:  205 Obj: -2.68E+01 Gap:       NaN
# Iter:   192 I:  0 Tm:      0.06 NLPi:    8 Dpth:    7 Lvs:  206 Obj: -2.86E+01 Gap:       NaN
# Iter:   193 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  208 Obj: -2.77E+01 Gap:       NaN
# Iter:   194 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  209 Obj: -2.86E+01 Gap:       NaN
# Iter:   195 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  211 Obj: -2.78E+01 Gap:       NaN
# Iter:   196 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  212 Obj: -2.85E+01 Gap:       NaN
# Iter:   197 I: -1 Tm:      0.01 NLPi:    1 Dpth:    7 Lvs:  211 Obj: -2.86E+01 Gap:       NaN
# Iter:   198 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  213 Obj: -2.84E+01 Gap:       NaN
# Iter:   199 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  215 Obj: -2.86E+01 Gap:       NaN
# Iter:   200 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  214 Obj: -2.86E+01 Gap:       NaN
# Iter:   201 I: -1 Tm:      0.03 NLPi:    2 Dpth:    8 Lvs:  213 Obj: -2.86E+01 Gap:       NaN
# Iter:   202 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  214 Obj: -2.85E+01 Gap:       NaN
# Iter:   203 I: -1 Tm:      0.01 NLPi:    1 Dpth:    6 Lvs:  213 Obj: -2.86E+01 Gap:       NaN
# Iter:   204 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  215 Obj: -2.76E+01 Gap:       NaN
# Iter:   205 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  216 Obj: -2.86E+01 Gap:       NaN
# Iter:   206 I: -1 Tm:      0.01 NLPi:    1 Dpth:    6 Lvs:  215 Obj: -2.86E+01 Gap:       NaN
# Iter:   207 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  217 Obj: -2.76E+01 Gap:       NaN
# Iter:   208 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  219 Obj: -2.86E+01 Gap:       NaN
# Iter:   209 I: -1 Tm:      0.01 NLPi:    1 Dpth:    7 Lvs:  218 Obj: -2.86E+01 Gap:       NaN
# Iter:   210 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  220 Obj: -2.68E+01 Gap:       NaN
# Iter:   211 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  221 Obj: -2.86E+01 Gap:       NaN
# Iter:   212 I: -1 Tm:      0.01 NLPi:    1 Dpth:    7 Lvs:  220 Obj: -2.86E+01 Gap:       NaN
# Iter:   213 I:  0 Tm:      0.04 NLPi:    4 Dpth:    7 Lvs:  222 Obj: -2.68E+01 Gap:       NaN
# Iter:   214 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  223 Obj: -2.86E+01 Gap:       NaN
# Iter:   215 I: -1 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  222 Obj: -2.86E+01 Gap:       NaN
# Iter:   216 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  223 Obj: -2.86E+01 Gap:       NaN
# Iter:   217 I: -1 Tm:      0.01 NLPi:    1 Dpth:   10 Lvs:  222 Obj: -2.86E+01 Gap:       NaN
# Iter:   218 I:  0 Tm:      0.04 NLPi:    5 Dpth:   10 Lvs:  224 Obj: -2.68E+01 Gap:       NaN
# Iter:   219 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  225 Obj: -2.86E+01 Gap:       NaN
# Iter:   220 I: -1 Tm:      0.04 NLPi:    4 Dpth:    9 Lvs:  224 Obj: -2.86E+01 Gap:       NaN
# Iter:   221 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  225 Obj: -2.58E+01 Gap:       NaN
# Iter:   222 I: -1 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  224 Obj: -2.86E+01 Gap:       NaN
# Iter:   223 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  226 Obj: -2.58E+01 Gap:       NaN
# Iter:   224 I: -1 Tm:      0.04 NLPi:    3 Dpth:    8 Lvs:  225 Obj: -2.86E+01 Gap:       NaN
# Iter:   225 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  227 Obj: -2.58E+01 Gap:       NaN
# Iter:   226 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  226 Obj: -2.86E+01 Gap:       NaN
# Iter:   227 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  228 Obj: -2.68E+01 Gap:       NaN
# Iter:   228 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  229 Obj: -2.85E+01 Gap:       NaN
# Iter:   229 I:  0 Tm:      0.04 NLPi:    4 Dpth:    7 Lvs:  231 Obj: -2.68E+01 Gap:       NaN
# Iter:   230 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  232 Obj: -2.86E+01 Gap:       NaN
# Iter:   231 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  234 Obj: -2.76E+01 Gap:       NaN
# Iter:   232 I:  0 Tm:      0.05 NLPi:    6 Dpth:    8 Lvs:  235 Obj: -2.86E+01 Gap:       NaN
# Iter:   233 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  237 Obj: -2.76E+01 Gap:       NaN
# Iter:   234 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  238 Obj: -2.85E+01 Gap:       NaN
# Iter:   235 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  237 Obj: -2.86E+01 Gap:       NaN
# Iter:   236 I: -1 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  236 Obj: -2.86E+01 Gap:       NaN
# Iter:   237 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  237 Obj: -2.86E+01 Gap:       NaN
# Iter:   238 I: -1 Tm:      0.04 NLPi:    3 Dpth:    7 Lvs:  236 Obj: -2.86E+01 Gap:       NaN
# Iter:   239 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  237 Obj: -2.84E+01 Gap:       NaN
# Iter:   240 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  239 Obj: -2.77E+01 Gap:       NaN
# Iter:   241 I:  0 Tm:      0.04 NLPi:    6 Dpth:    8 Lvs:  241 Obj: -2.85E+01 Gap:       NaN
# Iter:   242 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  240 Obj: -2.85E+01 Gap:       NaN
# Iter:   243 I: -1 Tm:      0.04 NLPi:    3 Dpth:    7 Lvs:  239 Obj: -2.85E+01 Gap:       NaN
# Iter:   244 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  240 Obj: -2.85E+01 Gap:       NaN
# Iter:   245 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  239 Obj: -2.85E+01 Gap:       NaN
# Iter:   246 I:  0 Tm:      0.04 NLPi:    4 Dpth:    6 Lvs:  241 Obj: -2.75E+01 Gap:       NaN
# Iter:   247 I:  0 Tm:      0.03 NLPi:    4 Dpth:    6 Lvs:  242 Obj: -2.85E+01 Gap:       NaN
# Iter:   248 I:  0 Tm:      0.04 NLPi:    5 Dpth:    7 Lvs:  244 Obj: -2.68E+01 Gap:       NaN
# Iter:   249 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  245 Obj: -2.85E+01 Gap:       NaN
# Iter:   250 I:  0 Tm:      0.04 NLPi:    5 Dpth:    8 Lvs:  247 Obj: -2.75E+01 Gap:       NaN
# Iter:   251 I:  0 Tm:      0.05 NLPi:    6 Dpth:    8 Lvs:  248 Obj: -2.85E+01 Gap:       NaN
# Iter:   252 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  250 Obj: -2.78E+01 Gap:       NaN
# Iter:   253 I:  0 Tm:      0.04 NLPi:    4 Dpth:    9 Lvs:  251 Obj: -2.85E+01 Gap:       NaN
# Iter:   254 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  250 Obj: -2.85E+01 Gap:       NaN
# Iter:   255 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  252 Obj: -2.78E+01 Gap:       NaN
# Iter:   256 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  253 Obj: -2.85E+01 Gap:       NaN
# Iter:   257 I: -1 Tm:      0.02 NLPi:    2 Dpth:    4 Lvs:  252 Obj: -2.85E+01 Gap:       NaN
# Iter:   258 I:  0 Tm:      0.03 NLPi:    4 Dpth:    4 Lvs:  254 Obj: -2.78E+01 Gap:       NaN
# Iter:   259 I:  0 Tm:      0.03 NLPi:    3 Dpth:    4 Lvs:  255 Obj: -2.85E+01 Gap:       NaN
# Iter:   260 I:  0 Tm:      0.04 NLPi:    5 Dpth:    5 Lvs:  257 Obj: -2.75E+01 Gap:       NaN
# Iter:   261 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:  258 Obj: -2.85E+01 Gap:       NaN
# Iter:   262 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:  260 Obj: -2.78E+01 Gap:       NaN
# Iter:   263 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  261 Obj: -2.85E+01 Gap:       NaN
# Iter:   264 I:  0 Tm:      0.04 NLPi:    5 Dpth:    7 Lvs:  263 Obj: -2.75E+01 Gap:       NaN
# Iter:   265 I:  0 Tm:      0.05 NLPi:    6 Dpth:    7 Lvs:  264 Obj: -2.85E+01 Gap:       NaN
# Iter:   266 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  266 Obj: -2.68E+01 Gap:       NaN
# Iter:   267 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  268 Obj: -2.85E+01 Gap:       NaN
# Iter:   268 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  267 Obj: -2.85E+01 Gap:       NaN
# Iter:   269 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  269 Obj: -2.85E+01 Gap:       NaN
# Iter:   270 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  271 Obj: -2.85E+01 Gap:       NaN
# Iter:   271 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs:  270 Obj: -2.85E+01 Gap:       NaN
# Iter:   272 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  272 Obj: -2.77E+01 Gap:       NaN
# Iter:   273 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  273 Obj: -2.85E+01 Gap:       NaN
# Iter:   274 I: -1 Tm:      0.03 NLPi:    2 Dpth:    7 Lvs:  272 Obj: -2.85E+01 Gap:       NaN
# Iter:   275 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  274 Obj: -2.68E+01 Gap:       NaN
# Iter:   276 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  275 Obj: -2.85E+01 Gap:       NaN
# Iter:   277 I: -1 Tm:      0.02 NLPi:    2 Dpth:    6 Lvs:  274 Obj: -2.85E+01 Gap:       NaN
# Iter:   278 I:  0 Tm:      0.04 NLPi:    5 Dpth:    6 Lvs:  276 Obj: -2.68E+01 Gap:       NaN
# Iter:   279 I:  0 Tm:      0.03 NLPi:    3 Dpth:    6 Lvs:  277 Obj: -2.85E+01 Gap:       NaN
# Iter:   280 I:  0 Tm:      0.04 NLPi:    5 Dpth:    7 Lvs:  279 Obj: -2.75E+01 Gap:       NaN
# Iter:   281 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  280 Obj: -2.85E+01 Gap:       NaN
# Iter:   282 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  282 Obj: -2.77E+01 Gap:       NaN
# Iter:   283 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  283 Obj: -2.85E+01 Gap:       NaN
# Iter:   284 I: -1 Tm:      0.03 NLPi:    2 Dpth:    9 Lvs:  282 Obj: -2.85E+01 Gap:       NaN
# Iter:   285 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  284 Obj: -2.75E+01 Gap:       NaN
# Iter:   286 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  285 Obj: -2.85E+01 Gap:       NaN
# Iter:   287 I: -1 Tm:      0.03 NLPi:    2 Dpth:    8 Lvs:  284 Obj: -2.85E+01 Gap:       NaN
# Iter:   288 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  286 Obj: -2.69E+01 Gap:       NaN
# Iter:   289 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  287 Obj: -2.85E+01 Gap:       NaN
# Iter:   290 I: -1 Tm:      0.02 NLPi:    2 Dpth:    5 Lvs:  286 Obj: -2.85E+01 Gap:       NaN
# Iter:   291 I:  0 Tm:      0.03 NLPi:    4 Dpth:    5 Lvs:  288 Obj: -2.78E+01 Gap:       NaN
# Iter:   292 I:  0 Tm:      0.02 NLPi:    3 Dpth:    5 Lvs:  289 Obj: -2.85E+01 Gap:       NaN
# Iter:   293 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  291 Obj: -2.68E+01 Gap:       NaN
# Iter:   294 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  292 Obj: -2.84E+01 Gap:       NaN
# Iter:   295 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  291 Obj: -2.85E+01 Gap:       NaN
# Iter:   296 I: -1 Tm:      0.03 NLPi:    2 Dpth:    7 Lvs:  290 Obj: -2.85E+01 Gap:       NaN
# Iter:   297 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  291 Obj: -2.85E+01 Gap:       NaN
# Iter:   298 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  293 Obj: -2.78E+01 Gap:       NaN
# Iter:   299 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  294 Obj: -2.85E+01 Gap:       NaN
# Iter:   300 I: -1 Tm:      0.04 NLPi:    4 Dpth:    9 Lvs:  293 Obj: -2.85E+01 Gap:       NaN
# Iter:   301 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  294 Obj: -2.84E+01 Gap:       NaN
# Iter:   302 I: -1 Tm:      0.06 NLPi:    6 Dpth:    8 Lvs:  293 Obj: -2.85E+01 Gap:       NaN
# Iter:   303 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  294 Obj: -2.85E+01 Gap:       NaN
# Iter:   304 I:  0 Tm:      0.05 NLPi:    6 Dpth:   10 Lvs:  296 Obj: -2.76E+01 Gap:       NaN
# Iter:   305 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  297 Obj: -2.85E+01 Gap:       NaN
# Iter:   306 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  299 Obj: -2.77E+01 Gap:       NaN
# Iter:   307 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  300 Obj: -2.85E+01 Gap:       NaN
# Iter:   308 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs:  299 Obj: -2.85E+01 Gap:       NaN
# Iter:   309 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  301 Obj: -2.77E+01 Gap:       NaN
# Iter:   310 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  302 Obj: -2.85E+01 Gap:       NaN
# Iter:   311 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  304 Obj: -2.80E+01 Gap:       NaN
# Iter:   312 I:  0 Tm:      0.04 NLPi:    4 Dpth:   10 Lvs:  305 Obj: -2.85E+01 Gap:       NaN
# Iter:   313 I:  0 Tm:      0.04 NLPi:    5 Dpth:   11 Lvs:  307 Obj: -2.80E+01 Gap:       NaN
# Iter:   314 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  308 Obj: -2.83E+01 Gap:       NaN
# Iter:   315 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  310 Obj: -2.77E+01 Gap:       NaN
# Iter:   316 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  311 Obj: -2.84E+01 Gap:       NaN
# Iter:   317 I:  0 Tm:      0.04 NLPi:    5 Dpth:   11 Lvs:  313 Obj: -2.73E+01 Gap:       NaN
# Iter:   318 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  314 Obj: -2.85E+01 Gap:       NaN
# Iter:   319 I: -1 Tm:      0.01 NLPi:    1 Dpth:    9 Lvs:  313 Obj: -2.85E+01 Gap:       NaN
# Iter:   320 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  312 Obj: -2.85E+01 Gap:       NaN
# Iter:   321 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  314 Obj: -2.58E+01 Gap:       NaN
# Iter:   322 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  313 Obj: -2.85E+01 Gap:       NaN
# Iter:   323 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  315 Obj: -2.85E+01 Gap:       NaN
# Iter:   324 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  317 Obj: -2.85E+01 Gap:       NaN
# Iter:   325 I: -1 Tm:      0.03 NLPi:    2 Dpth:    7 Lvs:  316 Obj: -2.85E+01 Gap:       NaN
# Iter:   326 I: -1 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  315 Obj: -2.85E+01 Gap:       NaN
# Iter:   327 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  316 Obj: -2.85E+01 Gap:       NaN
# Iter:   328 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  318 Obj: -2.77E+01 Gap:       NaN
# Iter:   329 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  319 Obj: -2.85E+01 Gap:       NaN
# Iter:   330 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  318 Obj: -2.85E+01 Gap:       NaN
# Iter:   331 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  319 Obj: -2.84E+01 Gap:       NaN
# Iter:   332 I:  0 Tm:      0.02 NLPi:    3 Dpth:    6 Lvs:  321 Obj: -2.85E+01 Gap:       NaN
# Iter:   333 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  320 Obj: -2.85E+01 Gap:       NaN
# Iter:   334 I: -1 Tm:      0.05 NLPi:    4 Dpth:    7 Lvs:  319 Obj: -2.85E+01 Gap:       NaN
# Iter:   335 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  320 Obj: -2.85E+01 Gap:       NaN
# Iter:   336 I: -1 Tm:      0.02 NLPi:    1 Dpth:    8 Lvs:  319 Obj: -2.85E+01 Gap:       NaN
# Iter:   337 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  320 Obj: -2.84E+01 Gap:       NaN
# Iter:   338 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  322 Obj: -2.78E+01 Gap:       NaN
# Iter:   339 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  323 Obj: -2.84E+01 Gap:       NaN
# Iter:   340 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  325 Obj: -2.77E+01 Gap:       NaN
# Iter:   341 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  326 Obj: -2.85E+01 Gap:       NaN
# Iter:   342 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  328 Obj: -2.67E+01 Gap:       NaN
# Iter:   343 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  329 Obj: -2.85E+01 Gap:       NaN
# Iter:   344 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  331 Obj: -2.75E+01 Gap:       NaN
# Iter:   345 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  332 Obj: -2.85E+01 Gap:       NaN
# Iter:   346 I: -1 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  331 Obj: -2.85E+01 Gap:       NaN
# Iter:   347 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  332 Obj: -2.82E+01 Gap:       NaN
# Iter:   348 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  331 Obj: -2.85E+01 Gap:       NaN
# Iter:   349 I:  0 Tm:      0.04 NLPi:    4 Dpth:    7 Lvs:  333 Obj: -2.78E+01 Gap:       NaN
# Iter:   350 I:  0 Tm:      0.03 NLPi:    3 Dpth:    7 Lvs:  334 Obj: -2.85E+01 Gap:       NaN
# Iter:   351 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  333 Obj: -2.85E+01 Gap:       NaN
# Iter:   352 I: -1 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  332 Obj: -2.85E+01 Gap:       NaN
# Iter:   353 I:  0 Tm:      0.04 NLPi:    4 Dpth:    8 Lvs:  333 Obj: -2.85E+01 Gap:       NaN
# Iter:   354 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  332 Obj: -2.85E+01 Gap:       NaN
# Iter:   355 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  334 Obj: -2.84E+01 Gap:       NaN
# Iter:   356 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  333 Obj: -2.85E+01 Gap:       NaN
# Iter:   357 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  335 Obj: -2.78E+01 Gap:       NaN
# Iter:   358 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  336 Obj: -2.85E+01 Gap:       NaN
# Iter:   359 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  335 Obj: -2.85E+01 Gap:       NaN
# Iter:   360 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  337 Obj: -2.77E+01 Gap:       NaN
# Iter:   361 I:  0 Tm:      0.03 NLPi:    4 Dpth:    7 Lvs:  338 Obj: -2.85E+01 Gap:       NaN
# Iter:   362 I: -1 Tm:      0.02 NLPi:    2 Dpth:    7 Lvs:  337 Obj: -2.85E+01 Gap:       NaN
# Iter:   363 I:  0 Tm:      0.04 NLPi:    4 Dpth:    7 Lvs:  339 Obj: -2.68E+01 Gap:       NaN
# Iter:   364 I:  0 Tm:      0.02 NLPi:    3 Dpth:    7 Lvs:  340 Obj: -2.85E+01 Gap:       NaN
# Iter:   365 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  342 Obj: -2.67E+01 Gap:       NaN
# Iter:   366 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  344 Obj: -2.59E+01 Gap:       NaN
# Iter:   367 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  346 Obj: -2.77E+01 Gap:       NaN
# Iter:   368 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  347 Obj: -2.85E+01 Gap:       NaN
# Iter:   369 I:  0 Tm:      0.04 NLPi:    4 Dpth:    9 Lvs:  349 Obj: -2.66E+01 Gap:       NaN
# Iter:   370 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  351 Obj: -2.85E+01 Gap:       NaN
# Iter:   371 I: -1 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  350 Obj: -2.85E+01 Gap:       NaN
# Iter:   372 I:  0 Tm:      0.02 NLPi:    2 Dpth:    8 Lvs:  352 Obj: -2.85E+01 Gap:       NaN
# Iter:   373 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  351 Obj: -2.85E+01 Gap:       NaN
# Iter:   374 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  350 Obj: -2.85E+01 Gap:       NaN
# Iter:   375 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  351 Obj: -2.85E+01 Gap:       NaN
# Iter:   376 I: -1 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  350 Obj: -2.85E+01 Gap:       NaN
# Iter:   377 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  352 Obj: -2.84E+01 Gap:       NaN
# Iter:   378 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  354 Obj: -2.85E+01 Gap:       NaN
# Iter:   379 I: -1 Tm:      0.01 NLPi:    1 Dpth:    9 Lvs:  353 Obj: -2.85E+01 Gap:       NaN
# Iter:   380 I: -1 Tm:      0.05 NLPi:    5 Dpth:    9 Lvs:  352 Obj: -2.85E+01 Gap:       NaN
# Iter:   381 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  353 Obj: -2.85E+01 Gap:       NaN
# Iter:   382 I: -1 Tm:      0.04 NLPi:    3 Dpth:   10 Lvs:  352 Obj: -2.85E+01 Gap:       NaN
# Iter:   383 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  354 Obj: -2.84E+01 Gap:       NaN
# Iter:   384 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs:  353 Obj: -2.85E+01 Gap:       NaN
# Iter:   385 I: -1 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  352 Obj: -2.85E+01 Gap:       NaN
# Iter:   386 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  353 Obj: -2.55E+01 Gap:       NaN
# Iter:   387 I:  0 Tm:      0.03 NLPi:    4 Dpth:    8 Lvs:  355 Obj: -2.66E+01 Gap:       NaN
# Iter:   388 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  356 Obj: -2.85E+01 Gap:       NaN
# Iter:   389 I: -1 Tm:      0.02 NLPi:    1 Dpth:   10 Lvs:  355 Obj: -2.85E+01 Gap:       NaN
# Iter:   390 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  357 Obj: -2.77E+01 Gap:       NaN
# Iter:   391 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  358 Obj: -2.84E+01 Gap:       NaN
# Iter:   392 I: -1 Tm:      0.01 NLPi:    1 Dpth:   11 Lvs:  357 Obj: -2.85E+01 Gap:       NaN
# Iter:   393 I:  0 Tm:      0.04 NLPi:    5 Dpth:   11 Lvs:  359 Obj: -2.68E+01 Gap:       NaN
# Iter:   394 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  360 Obj: -2.85E+01 Gap:       NaN
# Iter:   395 I: -1 Tm:      0.03 NLPi:    3 Dpth:   12 Lvs:  359 Obj: -2.85E+01 Gap:       NaN
# Iter:   396 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  361 Obj: -2.57E+01 Gap:       NaN
# Iter:   397 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  363 Obj: -2.85E+01 Gap:       NaN
# Iter:   398 I:  0 Tm:      0.02 NLPi:    3 Dpth:    8 Lvs:  365 Obj: -2.85E+01 Gap:       NaN
# Iter:   399 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  364 Obj: -2.85E+01 Gap:       NaN
# Iter:   400 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  363 Obj: -2.85E+01 Gap:       NaN
# Iter:   401 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  364 Obj: -2.84E+01 Gap:       NaN
# Iter:   402 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  366 Obj: -2.75E+01 Gap:       NaN
# Iter:   403 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  367 Obj: -2.84E+01 Gap:       NaN
# Iter:   404 I:  0 Tm:      0.03 NLPi:    4 Dpth:   14 Lvs:  369 Obj: -2.79E+01 Gap:       NaN
# Iter:   405 I:  0 Tm:      0.03 NLPi:    4 Dpth:   14 Lvs:  370 Obj: -2.85E+01 Gap:       NaN
# Iter:   406 I: -1 Tm:      0.04 NLPi:    3 Dpth:   15 Lvs:  369 Obj: -2.85E+01 Gap:       NaN
# Iter:   407 I:  0 Tm:      0.02 NLPi:    3 Dpth:   15 Lvs:  370 Obj: -2.83E+01 Gap:       NaN
# Iter:   408 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  372 Obj: -2.73E+01 Gap:       NaN
# Iter:   409 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  373 Obj: -2.84E+01 Gap:       NaN
# Iter:   410 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  375 Obj: -2.85E+01 Gap:       NaN
# Iter:   411 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs:  374 Obj: -2.85E+01 Gap:       NaN
# Iter:   412 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  376 Obj: -2.78E+01 Gap:       NaN
# Iter:   413 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  377 Obj: -2.84E+01 Gap:       NaN
# Iter:   414 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  378 Obj: -2.84E+01 Gap:       NaN
# Iter:   415 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  377 Obj: -2.85E+01 Gap:       NaN
# Iter:   416 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  379 Obj: -2.77E+01 Gap:       NaN
# Iter:   417 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  380 Obj: -2.85E+01 Gap:       NaN
# Iter:   418 I: -1 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  379 Obj: -2.85E+01 Gap:       NaN
# Iter:   419 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  380 Obj: -2.84E+01 Gap:       NaN
# Iter:   420 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs:  379 Obj: -2.85E+01 Gap:       NaN
# Iter:   421 I:  0 Tm:      0.05 NLPi:    5 Dpth:   12 Lvs:  381 Obj: -2.69E+01 Gap:       NaN
# Iter:   422 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  382 Obj: -2.85E+01 Gap:       NaN
# Iter:   423 I: -1 Tm:      0.04 NLPi:    4 Dpth:   13 Lvs:  381 Obj: -2.85E+01 Gap:       NaN
# Iter:   424 I:  0 Tm:      0.03 NLPi:    3 Dpth:   13 Lvs:  383 Obj: -2.55E+01 Gap:       NaN
# Iter:   425 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  385 Obj: -2.75E+01 Gap:       NaN
# Iter:   426 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  386 Obj: -2.84E+01 Gap:       NaN
# Iter:   427 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  388 Obj: -2.75E+01 Gap:       NaN
# Iter:   428 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  389 Obj: -2.84E+01 Gap:       NaN
# Iter:   429 I:  0 Tm:      0.04 NLPi:    5 Dpth:   14 Lvs:  391 Obj: -2.79E+01 Gap:       NaN
# Iter:   430 I:  0 Tm:      0.04 NLPi:    4 Dpth:   14 Lvs:  392 Obj: -2.85E+01 Gap:       NaN
# Iter:   431 I:  0 Tm:      0.04 NLPi:    5 Dpth:   15 Lvs:  394 Obj: -2.79E+01 Gap:       NaN
# Iter:   432 I:  0 Tm:      0.03 NLPi:    3 Dpth:   15 Lvs:  395 Obj: -2.85E+01 Gap:       NaN
# Iter:   433 I:  0 Tm:      0.04 NLPi:    6 Dpth:    8 Lvs:  397 Obj: -2.68E+01 Gap:       NaN
# Iter:   434 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  398 Obj: -2.85E+01 Gap:       NaN
# Iter:   435 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  400 Obj: -2.77E+01 Gap:       NaN
# Iter:   436 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  401 Obj: -2.85E+01 Gap:       NaN
# Iter:   437 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs:  400 Obj: -2.85E+01 Gap:       NaN
# Iter:   438 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  402 Obj: -2.77E+01 Gap:       NaN
# Iter:   439 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  403 Obj: -2.85E+01 Gap:       NaN
# Iter:   440 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs:  402 Obj: -2.85E+01 Gap:       NaN
# Iter:   441 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  404 Obj: -2.78E+01 Gap:       NaN
# Iter:   442 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  405 Obj: -2.85E+01 Gap:       NaN
# Iter:   443 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  407 Obj: -2.78E+01 Gap:       NaN
# Iter:   444 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  408 Obj: -2.85E+01 Gap:       NaN
# Iter:   445 I: -1 Tm:      0.02 NLPi:    1 Dpth:   16 Lvs:  407 Obj: -2.85E+01 Gap:       NaN
# Iter:   446 I:  0 Tm:      0.02 NLPi:    3 Dpth:   16 Lvs:  408 Obj: -2.82E+01 Gap:       NaN
# Iter:   447 I: -1 Tm:      0.07 NLPi:    4 Dpth:   10 Lvs:  407 Obj: -2.85E+01 Gap:       NaN
# Iter:   448 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  408 Obj: -2.84E+01 Gap:       NaN
# Iter:   449 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  410 Obj: -2.73E+01 Gap:       NaN
# Iter:   450 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  411 Obj: -2.83E+01 Gap:       NaN
# Iter:   451 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  413 Obj: -2.73E+01 Gap:       NaN
# Iter:   452 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  414 Obj: -2.83E+01 Gap:       NaN
# Iter:   453 I:  0 Tm:      0.03 NLPi:    4 Dpth:   11 Lvs:  416 Obj: -2.68E+01 Gap:       NaN
# Iter:   454 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  417 Obj: -2.85E+01 Gap:       NaN
# Iter:   455 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  419 Obj: -2.73E+01 Gap:       NaN
# Iter:   456 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  420 Obj: -2.83E+01 Gap:       NaN
# Iter:   457 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  422 Obj: -2.77E+01 Gap:       NaN
# Iter:   458 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  423 Obj: -2.83E+01 Gap:       NaN
# Iter:   459 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  425 Obj: -2.76E+01 Gap:       NaN
# Iter:   460 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  426 Obj: -2.84E+01 Gap:       NaN
# Iter:   461 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  428 Obj: -2.77E+01 Gap:       NaN
# Iter:   462 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  429 Obj: -2.83E+01 Gap:       NaN
# Iter:   463 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  431 Obj: -2.75E+01 Gap:       NaN
# Iter:   464 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  432 Obj: -2.84E+01 Gap:       NaN
# Iter:   465 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  434 Obj: -2.78E+01 Gap:       NaN
# Iter:   466 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  435 Obj: -2.83E+01 Gap:       NaN
# Iter:   467 I:  0 Tm:      0.03 NLPi:    4 Dpth:   11 Lvs:  437 Obj: -2.77E+01 Gap:       NaN
# Iter:   468 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  438 Obj: -2.83E+01 Gap:       NaN
# Iter:   469 I:  0 Tm:      0.06 NLPi:    7 Dpth:    8 Lvs:  440 Obj: -2.77E+01 Gap:       NaN
# Iter:   470 I:  0 Tm:      0.03 NLPi:    3 Dpth:    8 Lvs:  441 Obj: -2.84E+01 Gap:       NaN
# Iter:   471 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  440 Obj: -2.84E+01 Gap:       NaN
# Iter:   472 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs:  441 Obj: -2.84E+01 Gap:       NaN
# Iter:   473 I: -1 Tm:      0.04 NLPi:    4 Dpth:   10 Lvs:  440 Obj: -2.84E+01 Gap:       NaN
# Iter:   474 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  442 Obj: -2.83E+01 Gap:       NaN
# Iter:   475 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  444 Obj: -2.85E+01 Gap:       NaN
# Iter:   476 I: -1 Tm:      0.01 NLPi:    1 Dpth:   12 Lvs:  443 Obj: -2.85E+01 Gap:       NaN
# Iter:   477 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs:  442 Obj: -2.85E+01 Gap:       NaN
# Iter:   478 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  443 Obj: -2.83E+01 Gap:       NaN
# Iter:   479 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  444 Obj: -2.84E+01 Gap:       NaN
# Iter:   480 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  446 Obj: -2.78E+01 Gap:       NaN
# Iter:   481 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs:  447 Obj: -2.84E+01 Gap:       NaN
# Iter:   482 I: -1 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs:  446 Obj: -2.84E+01 Gap:       NaN
# Iter:   483 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  447 Obj: -2.83E+01 Gap:       NaN
# Iter:   484 I:  0 Tm:      0.03 NLPi:    4 Dpth:    9 Lvs:  449 Obj: -2.75E+01 Gap:       NaN
# Iter:   485 I:  0 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs:  450 Obj: -2.84E+01 Gap:       NaN
# Iter:   486 I:  0 Tm:      0.04 NLPi:    4 Dpth:   10 Lvs:  452 Obj: -2.67E+01 Gap:       NaN
# Iter:   487 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs:  453 Obj: -2.84E+01 Gap:       NaN
# Iter:   488 I: -1 Tm:      0.04 NLPi:    4 Dpth:   11 Lvs:  452 Obj: -2.84E+01 Gap:       NaN
# Iter:   489 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  453 Obj: -2.84E+01 Gap:       NaN
# Iter:   490 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs:  452 Obj: -2.84E+01 Gap:       NaN
# Iter:   491 I:  0 Tm:      0.03 NLPi:    4 Dpth:   12 Lvs:  453 Obj: -2.54E+01 Gap:       NaN
# Iter:   492 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  455 Obj: -2.75E+01 Gap:       NaN
# Iter:   493 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs:  456 Obj: -2.83E+01 Gap:       NaN
# Iter:   494 I:  0 Tm:      0.03 NLPi:    4 Dpth:   10 Lvs:  458 Obj: -2.75E+01 Gap:       NaN
# Iter:   495 I:  0 Tm:      0.04 NLPi:    3 Dpth:   10 Lvs:  459 Obj: -2.83E+01 Gap:       NaN
# Iter:   496 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  461 Obj: -2.84E+01 Gap:       NaN
# Iter:   497 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs:  463 Obj: -2.85E+01 Gap:       NaN
# Iter:   498 I: -1 Tm:      0.02 NLPi:    2 Dpth:   13 Lvs:  462 Obj: -2.85E+01 Gap:       NaN
# Iter:   499 I: -1 Tm:      0.04 NLPi:    4 Dpth:   13 Lvs:  461 Obj: -2.85E+01 Gap:       NaN
# Iter:   500 I:  0 Tm:      0.02 NLPi:    3 Dpth:   13 Lvs:  462 Obj: -2.85E+01 Gap:       NaN
# Iter:   501 I:  0 Tm:      0.03 NLPi:    4 Dpth:   14 Lvs:  464 Obj: -2.23E+01 Gap:       NaN
# Iter:   502 I:  0 Tm:      0.02 NLPi:    3 Dpth:   14 Lvs:  466 Obj: -2.59E+01 Gap:       NaN
# ...
# Iter:  6740 I:  0 Tm:      0.02 NLPi:    3 Dpth:   39 Lvs: 3290 Obj: -2.66E+01 Gap:       NaN
# Iter:  6741 I: -1 Tm:      0.01 NLPi:    1 Dpth:   21 Lvs: 3289 Obj: -2.68E+01 Gap:       NaN
# Iter:  6742 I: -1 Tm:      0.03 NLPi:    3 Dpth:   21 Lvs: 3288 Obj: -2.68E+01 Gap:       NaN
# Iter:  6743 I:  0 Tm:      0.02 NLPi:    2 Dpth:   21 Lvs: 3290 Obj: -2.14E+01 Gap:       NaN
# Iter:  6744 I:  0 Tm:      0.02 NLPi:    3 Dpth:   31 Lvs: 3292 Obj: -2.61E+01 Gap:       NaN
# Iter:  6745 I:  0 Tm:      0.03 NLPi:    3 Dpth:   31 Lvs: 3294 Obj: -2.67E+01 Gap:       NaN
# Iter:  6746 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3296 Obj: -2.66E+01 Gap:       NaN
# Iter:  6747 I:  0 Tm:      0.02 NLPi:    2 Dpth:   17 Lvs: 3298 Obj: -2.36E+01 Gap:       NaN
# Iter:  6748 I: -1 Tm:      0.01 NLPi:    1 Dpth:   17 Lvs: 3297 Obj: -2.68E+01 Gap:       NaN
# Iter:  6749 I: -1 Tm:      0.04 NLPi:    4 Dpth:   17 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6750 I:  0 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3297 Obj: -2.54E+01 Gap:       NaN
# Iter:  6751 I: -1 Tm:      0.02 NLPi:    1 Dpth:   21 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6752 I: -1 Tm:      0.02 NLPi:    2 Dpth:   21 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6753 I:  0 Tm:      0.03 NLPi:    3 Dpth:   21 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6754 I: -1 Tm:      0.01 NLPi:    1 Dpth:   21 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6755 I: -1 Tm:      0.03 NLPi:    2 Dpth:   21 Lvs: 3294 Obj: -2.68E+01 Gap:       NaN
# Iter:  6756 I:  0 Tm:      0.02 NLPi:    3 Dpth:   21 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6757 I: -1 Tm:      0.03 NLPi:    3 Dpth:   22 Lvs: 3294 Obj: -2.68E+01 Gap:       NaN
# Iter:  6758 I:  0 Tm:      0.03 NLPi:    4 Dpth:   22 Lvs: 3296 Obj: -2.44E+01 Gap:       NaN
# Iter:  6759 I: -1 Tm:      0.03 NLPi:    3 Dpth:   22 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6760 I:  0 Tm:      0.05 NLPi:    4 Dpth:   22 Lvs: 3297 Obj: -2.44E+01 Gap:       NaN
# Iter:  6761 I: -1 Tm:      0.03 NLPi:    2 Dpth:   21 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6762 I:  0 Tm:      0.02 NLPi:    3 Dpth:   21 Lvs: 3297 Obj: -2.67E+01 Gap:       NaN
# Iter:  6763 I: -1 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6764 I:  0 Tm:      0.02 NLPi:    3 Dpth:   23 Lvs: 3297 Obj: -2.47E+01 Gap:       NaN
# Iter:  6765 I: -1 Tm:      0.01 NLPi:    1 Dpth:   16 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6766 I: -1 Tm:      0.03 NLPi:    3 Dpth:   16 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6767 I: -1 Tm:      0.02 NLPi:    1 Dpth:   16 Lvs: 3294 Obj: -2.68E+01 Gap:       NaN
# Iter:  6768 I: -1 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3293 Obj: -2.68E+01 Gap:       NaN
# Iter:  6769 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3295 Obj: -2.43E+01 Gap:       NaN
# Iter:  6770 I: -1 Tm:      0.01 NLPi:    1 Dpth:   22 Lvs: 3294 Obj: -2.68E+01 Gap:       NaN
# Iter:  6771 I:  0 Tm:      0.03 NLPi:    4 Dpth:   22 Lvs: 3296 Obj: -2.58E+01 Gap:       NaN
# Iter:  6772 I:  0 Tm:      0.03 NLPi:    3 Dpth:   22 Lvs: 3297 Obj: -2.68E+01 Gap:       NaN
# Iter:  6773 I: -1 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6774 I:  0 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3297 Obj: -2.54E+01 Gap:       NaN
# Iter:  6775 I: -1 Tm:      0.01 NLPi:    1 Dpth:   17 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6776 I: -1 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3295 Obj: -2.68E+01 Gap:       NaN
# Iter:  6777 I:  0 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3297 Obj: -2.68E+01 Gap:       NaN
# Iter:  6778 I: -1 Tm:      0.02 NLPi:    1 Dpth:   17 Lvs: 3296 Obj: -2.68E+01 Gap:       NaN
# Iter:  6779 I:  0 Tm:      0.03 NLPi:    4 Dpth:   17 Lvs: 3298 Obj: -2.61E+01 Gap:       NaN
# Iter:  6780 I:  0 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6781 I: -1 Tm:      0.01 NLPi:    1 Dpth:   17 Lvs: 3299 Obj: -2.68E+01 Gap:       NaN
# Iter:  6782 I: -1 Tm:      0.02 NLPi:    2 Dpth:   17 Lvs: 3298 Obj: -2.68E+01 Gap:       NaN
# Iter:  6783 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3300 Obj: -2.59E+01 Gap:       NaN
# Iter:  6784 I: -1 Tm:      0.02 NLPi:    2 Dpth:   18 Lvs: 3299 Obj: -2.68E+01 Gap:       NaN
# Iter:  6785 I:  0 Tm:      0.03 NLPi:    4 Dpth:   18 Lvs: 3301 Obj: -2.61E+01 Gap:       NaN
# Iter:  6786 I:  0 Tm:      0.03 NLPi:    3 Dpth:   18 Lvs: 3302 Obj: -2.55E+01 Gap:       NaN
# Iter:  6787 I: -1 Tm:      0.01 NLPi:    1 Dpth:   17 Lvs: 3301 Obj: -2.68E+01 Gap:       NaN
# Iter:  6788 I: -1 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6789 I:  0 Tm:      0.03 NLPi:    4 Dpth:   17 Lvs: 3302 Obj: -2.48E+01 Gap:       NaN
# Iter:  6790 I: -1 Tm:      0.02 NLPi:    2 Dpth:   18 Lvs: 3301 Obj: -2.68E+01 Gap:       NaN
# Iter:  6791 I: -1 Tm:      0.04 NLPi:    3 Dpth:   18 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6792 I:  0 Tm:      0.02 NLPi:    3 Dpth:   18 Lvs: 3301 Obj: -2.55E+01 Gap:       NaN
# Iter:  6793 I: -1 Tm:      0.02 NLPi:    1 Dpth:   27 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6794 I: -1 Tm:      0.02 NLPi:    2 Dpth:   27 Lvs: 3299 Obj: -2.68E+01 Gap:       NaN
# Iter:  6795 I:  0 Tm:      0.02 NLPi:    3 Dpth:   27 Lvs: 3300 Obj: -2.67E+01 Gap:       NaN
# Iter:  6796 I: -1 Tm:      0.02 NLPi:    2 Dpth:   19 Lvs: 3299 Obj: -2.68E+01 Gap:       NaN
# Iter:  6797 I:  0 Tm:      0.02 NLPi:    4 Dpth:   19 Lvs: 3301 Obj: -2.60E+01 Gap:       NaN
# Iter:  6798 I:  0 Tm:      0.02 NLPi:    3 Dpth:   19 Lvs: 3303 Obj: -2.67E+01 Gap:       NaN
# Iter:  6799 I: -1 Tm:      0.02 NLPi:    2 Dpth:   17 Lvs: 3302 Obj: -2.68E+01 Gap:       NaN
# Iter:  6800 I: -1 Tm:      0.02 NLPi:    2 Dpth:   17 Lvs: 3301 Obj: -2.68E+01 Gap:       NaN
# Iter:  6801 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3302 Obj: -2.64E+01 Gap:       NaN
# Iter:  6802 I: -1 Tm:      0.02 NLPi:    1 Dpth:   19 Lvs: 3301 Obj: -2.68E+01 Gap:       NaN
# Iter:  6803 I: -1 Tm:      0.02 NLPi:    3 Dpth:   19 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6804 I:  0 Tm:      0.02 NLPi:    3 Dpth:   19 Lvs: 3301 Obj: -2.67E+01 Gap:       NaN
# Iter:  6805 I: -1 Tm:      0.01 NLPi:    1 Dpth:   25 Lvs: 3300 Obj: -2.68E+01 Gap:       NaN
# Iter:  6806 I:  0 Tm:      0.02 NLPi:    3 Dpth:   25 Lvs: 3302 Obj: -2.62E+01 Gap:       NaN
# Iter:  6807 I:  0 Tm:      0.02 NLPi:    3 Dpth:   25 Lvs: 3303 Obj: -2.64E+01 Gap:       NaN
# Iter:  6808 I:  0 Tm:      0.03 NLPi:    4 Dpth:   26 Lvs: 3305 Obj: -2.62E+01 Gap:       NaN
# Iter:  6809 I:  0 Tm:      0.02 NLPi:    3 Dpth:   26 Lvs: 3306 Obj: -2.68E+01 Gap:       NaN
# Iter:  6810 I: -1 Tm:      0.02 NLPi:    1 Dpth:   27 Lvs: 3305 Obj: -2.68E+01 Gap:       NaN
# Iter:  6811 I:  0 Tm:      0.04 NLPi:    5 Dpth:   27 Lvs: 3306 Obj: -2.65E+01 Gap:       NaN
# Iter:  6812 I:  0 Tm:      0.02 NLPi:    3 Dpth:   32 Lvs: 3308 Obj: -2.54E+01 Gap:       NaN
# Iter:  6813 I:  0 Tm:      0.02 NLPi:    3 Dpth:   32 Lvs: 3309 Obj: -2.68E+01 Gap:       NaN
# Iter:  6814 I: -1 Tm:      0.02 NLPi:    2 Dpth:   33 Lvs: 3308 Obj: -2.68E+01 Gap:       NaN
# Iter:  6815 I:  0 Tm:      0.03 NLPi:    3 Dpth:   33 Lvs: 3309 Obj: -2.67E+01 Gap:       NaN
# Iter:  6816 I: -1 Tm:      0.01 NLPi:    1 Dpth:   23 Lvs: 3308 Obj: -2.68E+01 Gap:       NaN
# Iter:  6817 I:  0 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3310 Obj: -2.57E+01 Gap:       NaN
# Iter:  6818 I:  0 Tm:      0.02 NLPi:    3 Dpth:   23 Lvs: 3311 Obj: -2.67E+01 Gap:       NaN
# Iter:  6819 I: -1 Tm:      0.01 NLPi:    1 Dpth:   23 Lvs: 3310 Obj: -2.68E+01 Gap:       NaN
# Iter:  6820 I:  0 Tm:      0.03 NLPi:    4 Dpth:   23 Lvs: 3312 Obj: -2.57E+01 Gap:       NaN
# Iter:  6821 I:  0 Tm:      0.02 NLPi:    3 Dpth:   23 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6822 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6823 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6824 I: -1 Tm:      0.04 NLPi:    3 Dpth:   12 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6825 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6826 I: -1 Tm:      0.02 NLPi:    2 Dpth:   13 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6827 I:  0 Tm:      0.03 NLPi:    3 Dpth:   13 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6828 I: -1 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6829 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6830 I: -1 Tm:      0.02 NLPi:    1 Dpth:   12 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6831 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs: 3311 Obj: -2.68E+01 Gap:       NaN
# Iter:  6832 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3312 Obj: -2.67E+01 Gap:       NaN
# Iter:  6833 I:  0 Tm:      0.02 NLPi:    3 Dpth:   23 Lvs: 3314 Obj: -2.63E+01 Gap:       NaN
# Iter:  6834 I:  0 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3315 Obj: -2.66E+01 Gap:       NaN
# Iter:  6835 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6836 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3315 Obj: -2.67E+01 Gap:       NaN
# Iter:  6837 I: -1 Tm:      0.02 NLPi:    1 Dpth:    9 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6838 I: -1 Tm:      0.02 NLPi:    2 Dpth:    9 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6839 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6840 I: -1 Tm:      0.03 NLPi:    3 Dpth:    9 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6841 I:  0 Tm:      0.02 NLPi:    3 Dpth:    9 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6842 I: -1 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6843 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs: 3314 Obj: -2.67E+01 Gap:       NaN
# Iter:  6844 I: -1 Tm:      0.02 NLPi:    2 Dpth:   16 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6845 I:  0 Tm:      0.03 NLPi:    3 Dpth:   16 Lvs: 3314 Obj: -2.67E+01 Gap:       NaN
# Iter:  6846 I: -1 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6847 I:  0 Tm:      0.03 NLPi:    3 Dpth:   10 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6848 I: -1 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6849 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3314 Obj: -2.67E+01 Gap:       NaN
# Iter:  6850 I: -1 Tm:      0.02 NLPi:    2 Dpth:   11 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6851 I:  0 Tm:      0.03 NLPi:    3 Dpth:   11 Lvs: 3314 Obj: -2.68E+01 Gap:       NaN
# Iter:  6852 I: -1 Tm:      0.02 NLPi:    2 Dpth:   12 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6853 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3314 Obj: -2.67E+01 Gap:       NaN
# Iter:  6854 I: -1 Tm:      0.02 NLPi:    1 Dpth:   12 Lvs: 3313 Obj: -2.68E+01 Gap:       NaN
# Iter:  6855 I: -1 Tm:      0.03 NLPi:    3 Dpth:   12 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6856 I:  0 Tm:      0.02 NLPi:    3 Dpth:   12 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6857 I: -1 Tm:      0.03 NLPi:    2 Dpth:   11 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6858 I:  0 Tm:      0.02 NLPi:    3 Dpth:   11 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6859 I: -1 Tm:      0.02 NLPi:    2 Dpth:   24 Lvs: 3312 Obj: -2.68E+01 Gap:       NaN
# Iter:  6860 I:  0 Tm:      0.03 NLPi:    5 Dpth:   24 Lvs: 3313 Obj: -2.67E+01 Gap:       NaN
# Iter:  6861 I:  0 Tm:      0.02 NLPi:    3 Dpth:   17 Lvs: 3315 Obj: -2.59E+01 Gap:       NaN
# Iter:  6862 I:  0 Tm:      0.03 NLPi:    3 Dpth:   17 Lvs: 3316 Obj: -2.67E+01 Gap:       NaN
# Iter:  6863 I: -1 Tm:      0.03 NLPi:    3 Dpth:   29 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6864 I:  0 Tm:      0.03 NLPi:    3 Dpth:   29 Lvs: 3316 Obj: -2.68E+01 Gap:       NaN
# Iter:  6865 I: -1 Tm:      0.03 NLPi:    3 Dpth:   30 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6866 I:  0 Tm:      0.03 NLPi:    3 Dpth:   30 Lvs: 3316 Obj: -2.68E+01 Gap:       NaN
# Iter:  6867 I: -1 Tm:      0.03 NLPi:    3 Dpth:   31 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6868 I:  0 Tm:      0.03 NLPi:    3 Dpth:   31 Lvs: 3316 Obj: -2.47E+01 Gap:       NaN
# Iter:  6869 I: -1 Tm:      0.02 NLPi:    2 Dpth:   13 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6870 I:  0 Tm:      0.02 NLPi:    3 Dpth:   13 Lvs: 3316 Obj: -2.67E+01 Gap:       NaN
# Iter:  6871 I: -1 Tm:      0.04 NLPi:    3 Dpth:   18 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6872 I:  0 Tm:      0.02 NLPi:    3 Dpth:   18 Lvs: 3316 Obj: -2.68E+01 Gap:       NaN
# Iter:  6873 I: -1 Tm:      0.03 NLPi:    3 Dpth:   18 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6874 I:  0 Tm:      0.02 NLPi:    3 Dpth:   18 Lvs: 3316 Obj: -2.68E+01 Gap:       NaN
# Iter:  6875 I: -1 Tm:      0.04 NLPi:    3 Dpth:   19 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6876 I:  0 Tm:      0.02 NLPi:    3 Dpth:   19 Lvs: 3316 Obj: -2.49E+01 Gap:       NaN
# Iter:  6877 I: -1 Tm:      0.04 NLPi:    3 Dpth:   19 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6878 I:  0 Tm:      0.02 NLPi:    3 Dpth:   19 Lvs: 3316 Obj: -2.49E+01 Gap:       NaN
# Iter:  6879 I: -1 Tm:      0.03 NLPi:    3 Dpth:   22 Lvs: 3315 Obj: -2.68E+01 Gap:       NaN
# Iter:  6880 I:  0 Tm:      0.02 NLPi:    3 Dpth:   22 Lvs: 3316 Obj: -2.67E+01 Gap:       NaN
# Iter:  6881 I:  0 Tm:      0.02 NLPi:    3 Dpth:   31 Lvs: 3318 Obj: -2.61E+01 Gap:       NaN
# Iter:  6882 I:  0 Tm:      0.02 NLPi:    3 Dpth:   31 Lvs: 3319 Obj: -2.68E+01 Gap:       NaN
# Iter:  6883 I:  0 Tm:      0.02 NLPi:    3 Dpth:   39 Lvs: 3321 Obj: -2.58E+01 Gap:       NaN
# Iter:  6884 I:  0 Tm:      0.03 NLPi:    3 Dpth:   39 Lvs: 3322 Obj: -2.66E+01 Gap:       NaN
# Iter:  6885 I: -1 Tm:      0.01 NLPi:    1 Dpth:   18 Lvs: 3321 Obj: -2.68E+01 Gap:       NaN
# Iter:  6886 I:  0 Tm:      0.03 NLPi:    4 Dpth:   18 Lvs: 3322 Obj: -2.67E+01 Gap:       NaN
# Iter:  6887 I: -1 Tm:      0.02 NLPi:    1 Dpth:   34 Lvs: 3321 Obj: -2.68E+01 Gap:       NaN
# Iter:  6888 I: -1 Tm:      0.04 NLPi:    3 Dpth:   34 Lvs: 3320 Obj: -2.68E+01 Gap:       NaN
# Iter:  6889 I:  0 Tm:      0.03 NLPi:    3 Dpth:   34 Lvs: 3321 Obj: -2.62E+01 Gap:       NaN
# Iter:  6890 I: -1 Tm:      0.02 NLPi:    1 Dpth:   32 Lvs: 3320 Obj: -2.68E+01 Gap:       NaN
# Iter:  6891 I: -1 Tm:      0.03 NLPi:    3 Dpth:   32 Lvs: 3319 Obj: -2.68E+01 Gap:       NaN
# Iter:  6892 I:  0 Tm:      0.03 NLPi:    3 Dpth:   32 Lvs: 3320 Obj: -2.68E+01 Gap:       NaN
# Iter:  6893 I: -1 Tm:      0.04 NLPi:    3 Dpth:   33 Lvs: 3319 Obj: -2.68E+01 Gap:       NaN
# Iter:  6894 I:  0 Tm:      0.03 NLPi:    4 Dpth:   33 Lvs: 3320 Obj: -2.46E+01 Gap:       NaN
# Iter:  6895 I: -1 Tm:      0.03 NLPi:    3 Dpth:   32 Lvs: 3319 Obj: -2.68E+01 Gap:       NaN
# Iter:  6896 I:  0 Tm:      0.03 NLPi:    4 Dpth:   32 Lvs: 3321 Obj: -2.67E+01 Gap:       NaN
# Iter:  6897 I: -1 Tm:      0.03 NLPi:    2 Dpth:   10 Lvs: 3320 Obj: -2.68E+01 Gap:       NaN
# Iter:  6898 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs: 3322 Obj: -2.67E+01 Gap:       NaN
# Iter:  6899 I: -1 Tm:      0.02 NLPi:    2 Dpth:   10 Lvs: 3321 Obj: -2.68E+01 Gap:       NaN
# Iter:  6900 I:  0 Tm:      0.02 NLPi:    3 Dpth:   10 Lvs: 3322 Obj: -2.68E+01 Gap:       NaN
# Iter:  6901 I: -1 Tm:      0.01 NLPi:    1 Dpth:   23 Lvs: 3321 Obj: -2.68E+01 Gap:       NaN
# Iter:  6902 I: -1 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3320 Obj: -2.68E+01 Gap:       NaN
# Iter:  6903 I:  0 Tm:      0.03 NLPi:    3 Dpth:   23 Lvs: 3321 Obj: -2.46E+01 Gap:       NaN
# --Integer Solution:  -2.59E+01 Lowest Leaf:  -2.68E+01 Gap:   3.24E-02
# Iter:  6904 I:  0 Tm:      0.04 NLPi:    4 Dpth:   24 Lvs: 3321 Obj: -2.59E+01 Gap:  3.24E-02
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  181.8067 sec
#  Objective      :  -22.880000000000003
#  Successful solution
#  ---------------------------------------------------
#
#
# Maximized preference: 22.88
# Time spent for breakfast: 30.0 minutes
# Time spent for lunch: 33.0 minutes
# Time spent for dinner: 120.0 minutes

# %%
print("breakfast")
print(output_breakfast)
print("lunch")
print(output_lunch)
print("dinner")

print(output_dinner)
# Out:
# breakfast
# {'Broccolini Quinoa Pilaf': 1.0}
# lunch
# {'Slow Cooker Chicken and Dumplings': 3.0}
# dinner
# {'Broccolini Quinoa Pilaf': 1.0, 'Swiss Chard Wraps': 1.0, 'Vanilla Cream Cakes, Easy and Fluffy Holiday Cakes': 1.0}

# %%
print("breakfast")
print(output_breakfast)
print("lunch")
print(output_lunch)
print("dinner")

print(output_dinner)
# Out:
# breakfast
# {'Broccolini Quinoa Pilaf': 1.0}
# lunch
# {'Slow Cooker Chicken and Dumplings': 3.0}
# dinner
# {'Broccolini Quinoa Pilaf': 1.0, 'Swiss Chard Wraps': 1.0, 'Vanilla Cream Cakes, Easy and Fluffy Holiday Cakes': 1.0}
